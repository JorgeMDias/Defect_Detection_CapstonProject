# %% [markdown]
# # <center>*IMPACT PROJECT - GESTAMP*</center>
# ## <center>Defect Detection using Machine Learning</center>
# ### <center>Cleaning Data</center>
# _____

# %% [markdown]
# <img
#     src="https://www.gestamp.com/getattachment/c8d61c0f-e752-4156-8002-97e21ab43a3f/Imag2-2" width="2400" height="1000" align="center"/>
#
# ___

# %% [markdown]
# ## <center>*Table of Contents*</center>
# 1. [Data Cleaning](#1)
#     * 1.1. [Changing CSV file separator and creating Datetime objects](#1.1)
#     * 1.2. [Cleaning the Defects CSV file](#1.2)
# 2. [Merging](#2)
#     * 2.1. [Merging per Press](#2.1)
#     * 2.2. [Merging for All](#2.2)

# %% [markdown]
# <a id='1'></a>
#
# ## <center>*1. Data Cleaning*</center>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import zipfile
import glob
import os

# %% [markdown]
# <a id='1.1'></a>
#
# ### <center>*1.1. Changing CSV file separator and creating Datetime objects*</center>

# %%
# Zip file path
zip_file_path = "MPO.01.zip"

# Pattern to match CSV files
file_pattern = "*.csv"

# %%
# Open the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_file:
    # Get the file names matching the pattern for P03
    file_names = [file for file in zip_file.namelist() if file.endswith('.csv')]

    for file_name in file_names:
        # Extract the CSV file
        zip_file.extract(file_name)

        # Read the CSV file
        df = pd.read_csv(file_name, delimiter=";")

        # Keep only document name
        file_name = file_name.split("/")[-1]
        print(file_name)

        # Loop to replace "," in y-variable column and convert into float
        for column_name in df.columns:
            if df[column_name].dtype == object and df[column_name].str.contains(",").any():
                df[column_name] = df[column_name].str.replace(",", ".").astype(float)
        
        # Convert time columns into datetime
        for col_name in df.columns:
            if ("time" in col_name.lower()) & ("time" not in file_name.lower()):
                print(col_name)
                df[col_name] = pd.to_datetime(df[col_name].str.replace(" CET", ""))
            elif (col_name=="time") | (col_name=="time.value"):                         #exception for the one file that includes "Time" in the file name
                print(col_name)
                df[col_name] = pd.to_datetime(df[col_name].str.replace(" CET", ""))

        # Filter columns with float data type
        float_columns = df.select_dtypes(include=[float])

        #save the cleaned csv
        if file_name[:2] == "P0":
            df.to_csv(f"datasets/clean_csv/{file_name[:3]}/{file_name}")
        else:
            print("other")
            df.to_csv(f"datasets/clean_csv/{file_name}")
# Out:
# Defects.csv
# time
# other
# P01-AmbientHumidity-values.csv
# time
# time.value
# P01-AmbientTemperature-values.csv
# time
# time.value
# P01-ClutchBrakeTemperatureUnitOil-values.csv
# time
# time.value
# P01-ClutchBrakeWaterTemperature-values.csv
# time
# time.value
# P01-CushionOilDegradation-values.csv
# time
# time.value
# P01-CushionPumpMaxPower1-values.csv
# time
# time.value
# P01-CushionPumpMaxPower2-values.csv
# time
# time.value
# P01-CushionPumpMaxPower3-values.csv
# time
# time.value
# P01-CushionPumpMeanPower1-values.csv
# time
# time.value
# P01-CushionPumpMeanPower2-values.csv
# time
# time.value
# P01-CushionPumpMeanPower3-values.csv
# time
# time.value
# P01-CushionTemperatureUnitOil-values.csv
# time
# time.value
# P01-CushionWaterFlow-values.csv
# time
# time.value
# P01-CushionWaterTemperature-values.csv
# time
# time.value
# P01-Cylinder1MaxForce-values.csv
# time
# time.value
# P01-Cylinder1MaxParalelismErrorInBDC-values.csv
# time
# time.value
# P01-Cylinder1MaxParallelismInCycle-values.csv
# time
# time.value
# P01-Cylinder2MaxForce-values.csv
# time
# time.value
# P01-Cylinder2MaxParalelismErrorInBDC-values.csv
# time
# time.value
# P01-Cylinder2MaxParallelismInCycle-values.csv
# time
# time.value
# P01-Cylinder3MaxForce-values.csv
# time
# time.value
# P01-Cylinder3MaxParalelismErrorInBDC-values.csv
# time
# time.value
# P01-Cylinder3MaxParallelismInCycle-values.csv
# time
# time.value
# P01-Cylinder4MaxForce-values.csv
# time
# time.value
# P01-Cylinder4MaxParalelismErrorInBDC-values.csv
# time
# time.value
# P01-Cylinder4MaxParallelismInCycle-values.csv
# time
# time.value
# P01-Cylinder5MaxForce-values.csv
# time
# time.value
# P01-Cylinder5MaxParalelismErrorInBDC-values.csv
# time
# time.value
# P01-Cylinder5MaxParallelismInCycle-values.csv
# time
# time.value
# P01-Cylinder6MaxForce-values.csv
# time
# time.value
# P01-Cylinder6MaxParalelismErrorInBDC-values.csv
# time
# time.value
# P01-Cylinder6MaxParallelismInCycle-values.csv
# time
# time.value
# P01-Cylinder7MaxForce-values.csv
# time
# time.value
# P01-Cylinder7MaxParalelismErrorInBDC-values.csv
# time
# time.value
# P01-Cylinder7MaxParallelismInCycle-values.csv
# time
# time.value
# P01-Cylinder8MaxForce-values.csv
# time
# time.value
# P01-Cylinder8MaxParalelismErrorInBDC-values.csv
# time
# time.value
# P01-Cylinder8MaxParallelismInCycle-values.csv
# time
# time.value
# P01-DieReference.csv
# time
# time.reference
# P01-DieTemperature1-values.csv
# time
# time.value
# P01-DieTemperature2-values.csv
# time
# time.value
# P01-GasSpringPressure1-values.csv
# time
# time.value
# P01-GasSpringPressure2-values.csv
# time
# time.value
# P01-GasSpringPressure3-values.csv
# time
# time.value
# P01-Gear1MaxTorque-values.csv
# time
# time.value
# P01-Gear2MaxTorque-values.csv
# time
# time.value
# P01-Gear3MaxTorque-values.csv
# time
# time.value
# P01-HELMGaugesControl-values.csv
# time
# time.value
# P01-LubricationTemperatureUnitOil-values.csv
# time
# time.value
# P01-MainMotorMaxPower-values.csv
# time
# time.value
# P01-MainMotorMeanPower-values.csv
# time
# time.value
# P01-MaxForceFL-values.csv
# time
# time.value
# P01-MaxForceFR-values.csv
# time
# time.value
# P01-MaxForceRL-values.csv
# time
# time.value
# P01-MaxForceRR-values.csv
# time
# time.value
# P01-MaxOffCenteredLoadFR-values.csv
# time
# time.value
# P01-MaxOffCenteredLoadLR-values.csv
# time
# time.value
# P01-OverloadSystemPrechargePressure-values.csv
# time
# time.value
# P01-PartEnergy-values.csv
# time
# time.value
# P01-PressForceValueFL-values.csv
# time
# time.value
# P01-PressForceValueFR-values.csv
# time
# time.value
# P01-PressForceValueRL-values.csv
# time
# time.value
# P01-PressForceValueRR-values.csv
# time
# time.value
# P01-PressMode.csv
# time
# P01-PressSpeed-parameter.csv
# time
# time.param
# P01-ProcessEnergy-values.csv
# time
# time.value
# P01-RealBDCDistanceToPos1-parameter.csv
# time
# time.param
# P01-RealDeaccelerationOfCushion-parameter.csv
# time
# time.param
# P01-RealInitialAngleOffset-parameter.csv
# time
# time.param
# P01-RealInteligentCushionStatus-parameter.csv
# time
# time.param
# P01-RealPos1Cylinder1Force-parameter.csv
# time
# time.param
# P01-RealPos1Cylinder1Position-parameter.csv
# time
# time.param
# P01-RealPos1Cylinder2Force-parameter.csv
# time
# time.param
# P01-RealPos1Cylinder2Position-parameter.csv
# time
# time.param
# P01-RealPos1Cylinder3Force-parameter.csv
# time
# time.param
# P01-RealPos1Cylinder3Position-parameter.csv
# time
# time.param
# P01-RealPos1Cylinder4Force-parameter.csv
# time
# time.param
# P01-RealPos1Cylinder4Position-parameter.csv
# time
# time.param
# P01-RealPos1Cylinder5Force-parameter.csv
# time
# time.param
# P01-RealPos1Cylinder5Position-parameter.csv
# time
# time.param
# P01-RealPos1Cylinder6Force-parameter.csv
# time
# time.param
# P01-RealPos1Cylinder6Position-parameter.csv
# time
# time.param
# P01-RealPos1Cylinder7Force-parameter.csv
# time
# time.param
# P01-RealPos1Cylinder7Position-parameter.csv
# time
# time.param
# P01-RealPos1Cylinder8Force-parameter.csv
# time
# time.param
# P01-RealPos1Cylinder8Position-parameter.csv
# time
# time.param
# P01-RealPreacceleration-parameter.csv
# time
# time.param
# P01-RealPreaccelerationLength-parameter.csv
# time
# time.param
# P01-RealTDCDistanceToBDC-parameter.csv
# time
# time.param
# P01-RealTDCDistanceToTable-parameter.csv
# time
# time.param
# P01-RealVelocityOfContact-parameter.csv
# time
# time.param
# P01-RealVelocityOfOpening-parameter.csv
# time
# time.param
# P01-RealWaitingTimeInPos1-parameter.csv
# time
# P01-SlideAccelerationDown-values.csv
# time
# time.value
# P01-SlideAccelerationUp-values.csv
# time
# time.value
# P01-SlideAdjustment-values.csv
# time
# time.value
# P01-SlidePositionDown-values.csv
# time
# time.value
# P01-SlidePositionUp-values.csv
# time
# time.value
# P01-SlideSpeedDown-values.csv
# time
# time.value
# P01-SlideSpeedUp-values.csv
# time
# time.value
# P01-TotalMaxForce-values.csv
# time
# time.value
# P01-TotalPressForceValue-values.csv
# time
# time.value
# P01-WorkStatusCylinder-parameter.csv
# time
# time.param
# P01-WorkStatusCylinder-values.csv
# time
# time.value
# P02-ClutchBrakeTemperatureUnitOil-values.csv
# time
# time.value
# P02-ClutchBrakeWaterTemperature-values.csv
# time
# time.value
# P02-DieReference.csv
# time
# time.reference
# P02-Gear1MaxTorque-values.csv
# time
# time.value
# P02-Gear2MaxTorque-values.csv
# time
# time.value
# P02-Gear3MaxTorque-values.csv
# time
# time.value
# P02-HELMGaugesControl-values.csv
# time
# time.value
# P02-LubricationTemperatureUnitOil-values.csv
# time
# time.value
# P02-MainMotorMaxPower-values.csv
# time
# time.value
# P02-MainMotorMeanPower-values.csv
# time
# time.value
# P02-MaxForceFL-values.csv
# time
# time.value
# P02-MaxForceFR-values.csv
# time
# time.value
# P02-MaxForceRL-values.csv
# time
# time.value
# P02-MaxForceRR-values.csv
# time
# time.value
# P02-MaxOffCenteredLoadFR-values.csv
# time
# time.value
# P02-MaxOffCenteredLoadLR-values.csv
# time
# time.value
# P02-OverloadSystemPrechargePressure-values.csv
# time
# time.value
# P02-PartEnergy-values.csv
# time
# time.value
# P02-PressForceValueFL-values.csv
# time
# time.value
# P02-PressForceValueFR-values.csv
# time
# time.value
# P02-PressForceValueRL-values.csv
# time
# time.value
# P02-PressForceValueRR-values.csv
# time
# time.value
# P02-PressMode.csv
# time
# P02-PressSpeed-parameter.csv
# time
# time.param
# P02-ProcessEnergy-values.csv
# time
# time.value
# P02-RealDieChangePosition-parameter.csv
# time
# time.param
# P02-RealUpperCushionPressure-parameter.csv
# time
# time.param
# P02-SlideAccelerationDown-values.csv
# time
# time.value
# P02-SlideAccelerationUp-values.csv
# time
# time.value
# P02-SlideAdjustment-values.csv
# time
# time.value
# P02-SlidePositionDown-values.csv
# time
# time.value
# P02-SlidePositionUp-values.csv
# time
# time.value
# P02-SlideSpeedDown-values.csv
# time
# time.value
# P02-SlideSpeedUp-values.csv
# time
# time.value
# P02-TotalMaxForce-values.csv
# time
# time.value
# P02-TotalPressForceValue-values.csv
# time
# time.value
# P03-ClutchBrakeTemperatureUnitOil-values.csv
# time
# time.value
# P03-ClutchBrakeWaterTemperature-values.csv
# time
# time.value
# P03-DieReference.csv
# time
# time.reference
# P03-Gear1MaxTorque-values.csv
# time
# time.value
# P03-Gear2MaxTorque-values.csv
# time
# time.value
# P03-Gear3MaxTorque-values.csv
# time
# time.value
# P03-HELMGaugesControl-values.csv
# time
# time.value
# P03-LubricationTemperatureUnitOil-values.csv
# time
# time.value
# P03-MainMotorMaxPower-values.csv
# time
# time.value
# P03-MainMotorMeanPower-values.csv
# time
# time.value
# P03-MaxForceFL-values.csv
# time
# time.value
# P03-MaxForceFR-values.csv
# time
# time.value
# P03-MaxForceRL-values.csv
# time
# time.value
# P03-MaxForceRR-values.csv
# time
# time.value
# P03-MaxOffCenteredLoadFR-values.csv
# time
# time.value
# P03-MaxOffCenteredLoadLR-values.csv
# time
# time.value
# P03-OverloadSystemPrechargePressure-values.csv
# time
# time.value
# P03-PartEnergy-values.csv
# time
# time.value
# P03-PressForceValueFL-values.csv
# time
# time.value
# P03-PressForceValueFR-values.csv
# time
# time.value
# P03-PressForceValueRL-values.csv
# time
# time.value
# P03-PressForceValueRR-values.csv
# time
# time.value
# P03-PressMode.csv
# time
# P03-PressSpeed-parameter.csv
# time
# time.param
# P03-ProcessEnergy-values.csv
# time
# time.value
# P03-RealDieChangePosition-parameter.csv
# time
# time.param
# P03-RealUpperCushionPressure-parameter.csv
# time
# time.param
# P03-SlideAccelerationDown-values.csv
# time
# time.value
# P03-SlideAccelerationUp-values.csv
# time
# time.value
# P03-SlideAdjustment-values.csv
# time
# time.value
# P03-SlidePositionDown-values.csv
# time
# time.value
# P03-SlidePositionUp-values.csv
# time
# time.value
# P03-SlideSpeedDown-values.csv
# time
# time.value
# P03-SlideSpeedUp-values.csv
# time
# time.value
# P03-TotalMaxForce-values.csv
# time
# time.value
# P03-TotalPressForceValue-values.csv
# time
# time.value
# P04-ClutchBrakeTemperatureUnitOil-values.csv
# time
# time.value
# P04-ClutchBrakeWaterTemperature-values.csv
# time
# time.value
# P04-DieReference.csv
# time
# time.reference
# P04-Gear1MaxTorque-values.csv
# time
# time.value
# P04-Gear2MaxTorque-values.csv
# time
# time.value
# P04-Gear3MaxTorque-values.csv
# time
# time.value
# P04-HELMGaugesControl-values.csv
# time
# time.value
# P04-LubricationTemperatureUnitOil-values.csv
# time
# time.value
# P04-MainMotorMaxPower-values.csv
# time
# time.value
# P04-MainMotorMeanPower-values.csv
# time
# time.value
# P04-MaxForceFL-values.csv
# time
# time.value
# P04-MaxForceFR-values.csv
# time
# time.value
# P04-MaxForceRL-values.csv
# time
# time.value
# P04-MaxForceRR-values.csv
# time
# time.value
# P04-MaxOffCenteredLoadFR-values.csv
# time
# time.value
# P04-MaxOffCenteredLoadLR-values.csv
# time
# time.value
# P04-OverloadSystemPrechargePressure-values.csv
# time
# time.value
# P04-PartEnergy-values.csv
# time
# time.value
# P04-PressForceValueFL-values.csv
# time
# time.value
# P04-PressForceValueFR-values.csv
# time
# time.value
# P04-PressForceValueRL-values.csv
# time
# time.value
# P04-PressForceValueRR-values.csv
# time
# time.value
# P04-PressMode.csv
# time
# P04-PressSpeed-parameter.csv
# time
# time.param
# P04-ProcessEnergy-values.csv
# time
# time.value
# P04-RealDieChangePosition-parameter.csv
# time
# time.param
# P04-RealUpperCushionPressure-parameter.csv
# time
# time.param
# P04-SlideAccelerationDown-values.csv
# time
# time.value
# P04-SlideAccelerationUp-values.csv
# time
# time.value
# P04-SlideAdjustment-values.csv
# time
# time.value
# P04-SlidePositionDown-values.csv
# time
# time.value
# P04-SlidePositionUp-values.csv
# time
# time.value
# P04-SlideSpeedDown-values.csv
# time
# time.value
# P04-SlideSpeedUp-values.csv
# time
# time.value
# P04-TotalMaxForce-values.csv
# time
# time.value
# P04-TotalPressForceValue-values.csv
# time
# time.value
# P05-ClutchBrakeTemperatureUnitOil-values.csv
# time
# time.value
# P05-ClutchBrakeWaterTemperature-values.csv
# time
# time.value
# P05-DieReference.csv
# time
# time.reference
# P05-Gear1MaxTorque-values.csv
# time
# time.value
# P05-Gear2MaxTorque-values.csv
# time
# time.value
# P05-Gear3MaxTorque-values.csv
# time
# time.value
# P05-HELMGaugesControl-values.csv
# time
# time.value
# P05-LubricationTemperatureUnitOil-values.csv
# time
# time.value
# P05-MainMotorMaxPower-values.csv
# time
# time.value
# P05-MainMotorMeanPower-values.csv
# time
# time.value
# P05-MaxForceFL-values.csv
# time
# time.value
# P05-MaxForceFR-values.csv
# time
# time.value
# P05-MaxForceRL-values.csv
# time
# time.value
# P05-MaxForceRR-values.csv
# time
# time.value
# P05-MaxOffCenteredLoadFR-values.csv
# time
# time.value
# P05-MaxOffCenteredLoadLR-values.csv
# time
# time.value
# P05-OverloadSystemPrechargePressure-values.csv
# time
# time.value
# P05-PartEnergy-values.csv
# time
# time.value
# P05-PressForceValueFL-values.csv
# time
# time.value
# P05-PressForceValueFR-values.csv
# time
# time.value
# P05-PressForceValueRL-values.csv
# time
# time.value
# P05-PressForceValueRR-values.csv
# time
# time.value
# P05-PressMode.csv
# time
# P05-PressSpeed-parameter.csv
# time
# time.param
# P05-ProcessEnergy-values.csv
# time
# time.value
# P05-RealDieChangePosition-parameter.csv
# time
# time.param
# P05-RealUpperCushionPressure-parameter.csv
# time
# time.param
# P05-SlideAccelerationDown-values.csv
# time
# time.value
# P05-SlideAccelerationUp-values.csv
# time
# time.value
# P05-SlideAdjustment-values.csv
# time
# time.value
# P05-SlidePositionDown-values.csv
# time
# time.value
# P05-SlidePositionUp-values.csv
# time
# time.value
# P05-SlideSpeedDown-values.csv
# time
# time.value
# P05-SlideSpeedUp-values.csv
# time
# time.value
# P05-TotalMaxForce-values.csv
# time
# time.value
# P05-TotalPressForceValue-values.csv
# time
# time.value
# P06-ClutchBrakeTemperatureUnitOil-values.csv
# time
# time.value
# P06-ClutchBrakeWaterTemperature-values.csv
# time
# time.value
# P06-DieReference.csv
# time
# time.reference
# P06-Gear1MaxTorque-values.csv
# time
# time.value
# P06-Gear2MaxTorque-values.csv
# time
# time.value
# P06-Gear3MaxTorque-values.csv
# time
# time.value
# P06-HELMGaugesControl-values.csv
# time
# time.value
# P06-LubricationTemperatureUnitOil-values.csv
# time
# time.value
# P06-MainMotorMaxPower-values.csv
# time
# time.value
# P06-MainMotorMeanPower-values.csv
# time
# time.value
# P06-MaxForceFL-values.csv
# time
# time.value
# P06-MaxForceFR-values.csv
# time
# time.value
# P06-MaxForceRL-values.csv
# time
# time.value
# P06-MaxForceRR-values.csv
# time
# time.value
# P06-MaxOffCenteredLoadFR-values.csv
# time
# time.value
# P06-MaxOffCenteredLoadLR-values.csv
# time
# time.value
# P06-OverloadSystemPrechargePressure-values.csv
# time
# time.value
# P06-PartEnergy-values.csv
# time
# time.value
# P06-PressForceValueFL-values.csv
# time
# time.value
# P06-PressForceValueFR-values.csv
# time
# time.value
# P06-PressForceValueRL-values.csv
# time
# time.value
# P06-PressForceValueRR-values.csv
# time
# time.value
# P06-PressMode.csv
# time
# P06-PressSpeed-parameter.csv
# time
# time.param
# P06-ProcessEnergy-values.csv
# time
# time.value
# P06-RealDieChangePosition-parameter.csv
# time
# time.param
# P06-RealUpperCushionPressure-parameter.csv
# time
# time.param
# P06-SlideAccelerationDown-values.csv
# time
# time.value
# P06-SlideAccelerationUp-values.csv
# time
# time.value
# P06-SlideAdjustment-values.csv
# time
# time.value
# P06-SlidePositionDown-values.csv
# time
# time.value
# P06-SlidePositionUp-values.csv
# time
# time.value
# P06-SlideSpeedDown-values.csv
# time
# time.value
# P06-SlideSpeedUp-values.csv
# time
# time.value
# P06-TotalMaxForce-values.csv
# time
# time.value
# P06-TotalPressForceValue-values.csv
# time
# time.value
# TraceabilitySummary.csv
# time.start
# time.end
# other

# %% [markdown]
# <a id='1.2'></a>
#
# ### <center>*1.2. Cleaning the Defects CSV file*</center>

# %%
defects = pd.read_csv("datasets/clean_csv/defects.csv")

defects = defects.drop(columns="Unnamed: 0")

defects["Defect"] = defects["Defect"].str.split(r'\(|\)').str.get(1)
defects["Defect"] = defects["Defect"].fillna("Other")

defects.to_csv("datasets/merged_csv/Defects.csv")

# %% [markdown]
# <a id='2'></a>
#
# ## <center>*2. Data Merging*</center>

# %% [markdown]
# <a id='2.1'></a>
#
# ### <center> 2.1. Merging per Press </center>

# %%
def get_df_P0(num):
    # Directory where the CSV files are located
    directory = f"datasets/clean_csv/P0{num}"

    # Pattern to match CSV files
    file_pattern = "*.csv"

    # Get the file names matching the pattern for P03
    file_names = glob.glob(directory + "/" + file_pattern)


    value_df = pd.DataFrame()
    other_df = pd.DataFrame()

    for indx, file_name in enumerate(file_names):
        # Read the CSV file
        df = pd.read_csv(file_name)
        df = df.drop(columns="Unnamed: 0")

        #keep only document name
        file_name=file_name.split("\\")[1]
        print(file_name)

        if "value" in file_name:
            if indx == 0:
                value_df = df
                continue

            if "TraceabilityCode" in df.columns:                #check for traceability code in the columns
                merge_columns = ["TraceabilityCode", "time", "time.value"]
                
                value_df = pd.merge(value_df,df,how="outer",on=merge_columns,suffixes=("",f"_{indx}"))
        else:
            if other_df.empty:
                other_df = df
                continue
            if "TraceabilityCode" in df.columns:                #check for traceability code in the columns
                merge_columns = ["TraceabilityCode", "time"]
                
                other_df = pd.merge(other_df,df,how="outer",on=merge_columns,suffixes=("",f"_{indx}"))
    
    value_df = value_df.drop(columns="time.value")
    value_df = value_df.groupby(["TraceabilityCode", "time"]).mean(numeric_only=True).reset_index() #grouping all ["TraceabilityCode", "time"] duplicates and keep the avg

    return value_df, other_df

# %%
def merge_DieReference(value, other):
    merged_df = pd.merge(value, other[["TraceabilityCode","DieReference"]], on="TraceabilityCode")
    return merged_df

# %%
def df_to_csv(df, id, type=0):
    print(f"{id}_{type}")
    if type == 0:
        df.to_csv(f"datasets/merged_csv/{id}.csv")
    else:
        df.to_csv(f"datasets/merged_csv/P0{id}/P0{id}_{type}.csv")

# %%
values = []
others = []
for i in range (1,7):                                   #looping through every P0_ section of files, excluding P01
    df_value, df_other = get_df_P0(i)                   #merging every p0_ dataset together into one df, separated by P0_

    df_value = merge_DieReference(df_value, df_other)   #merge DieReference column to df_value
    
    values.append(df_value)                             #saving the sizes of the Dataframes
    others.append(df_other)

# %%
for i in range(0,len(values)):
    df_to_csv(values[i], i+1, "value")                #saving value dfs to csv
    if i != 0:
        df_to_csv(others[i], i+1, "other")            #saving other dfs to csv

# %% [markdown]
# #### <center> Run the fill_nans.ipynb file </center>

# %% [markdown]
# <a id='2.2'></a>
#
# ### <center> 2.2. Merging for All </center>

# %% [markdown]
# <center> Load in all the files </center>

# %%
zip_file_path = 'datasets/filled_csv/P01_filled.zip'

# Name of the CSV file inside the zip
csv_file_name = 'data.csv'

# Open the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_file:
    # Read the CSV file from the zip
    with zip_file.open(csv_file_name) as csv_file:
        # Read the CSV file as a DataFrame
        df = pd.read_csv(csv_file)

# %%
# Directory where the CSV files are located
directory = f"datasets/filled_csv"

# Pattern to match CSV files
file_pattern = "*.csv"

# Get the file names matching the pattern for P03
file_names = glob.glob(directory + "/" + file_pattern)

filled_dfs = [df]

for indx, file_name in enumerate(file_names):
    # Read the CSV file
    df = pd.read_csv(file_name)
    df = df.drop(columns=["Unnamed: 0","Unnamed: 0.1"])
    filled_dfs.append(df)

# %%
defects = pd.read_csv("datasets/merged_csv/Defects.csv")

# %% [markdown]
# <center> Merging </center>

# %%
global_csv = filled_dfs[0]
for i in range(1,len(filled_dfs)):
    global_csv = pd.merge(global_csv,filled_dfs[i],how="outer",on=["TraceabilityCode"],suffixes=("",f"_0{i+1}"))

# %%
global_csv = pd.merge(global_csv,defects[["TraceabilityCode","Defect"]],how="left",on=["TraceabilityCode"])
global_csv = global_csv.drop(columns=["Unnamed: 0","Unnamed: 0.1"])

# %%
global_csv.head()

# %%
global_csv.to_csv("datasets/filled_csv/global.csv")

# %%
def compress_csv_to_zip(csv_file_path, zip_file_path):
    with zipfile.ZipFile(zip_file_path, 'w', compression=zipfile.ZIP_DEFLATED) as zipf:
        zipf.write(csv_file_path, arcname='data.csv')
    
    os.remove(csv_file_path)

# Specify the paths to your CSV and the desired output ZIP file
csv_file_path = 'datasets/filled_csv/global.csv'
zip_file_path = 'datasets/filled_csv/global.zip'

# Call the function to compress the CSV into a ZIP archive
compress_csv_to_zip(csv_file_path, zip_file_path)
